# %% [markdown]
# # init scriptによる日本語フォントのインストール
# <br>
# - 以下のスクリプトを実行すると、DBFSの `/databricks/scripts/japanese-font-install.sh` にinit scriptが作成されます。
# - Clustersにて、日本語フォントを使用するクラスターにinit scriptを指定してください。
# ![](https://sajpstorage.blob.core.windows.net/workshop202103-r-mlflow/Screen Shot 2021-02-21 at 11.12.15.png)
#
# ** 参考情報 **
# - [Cluster node initialization scripts — Databricks Documentation](https://docs.databricks.com/clusters/init-scripts.html)
# - [Configure clusters — Databricks Documentation](https://docs.databricks.com/clusters/configure.html#cluster-log-delivery) init scriptの動作をロギングすることができます

# %%
# init script格納ディレクトリの作成
dbutils.fs.mkdirs("dbfs:/databricks/scripts/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[1]: True</div>

# %%
# init scriptの作成
dbutils.fs.put("/databricks/scripts/japanese-font-install.sh","""
#!/bin/bash
apt-get install fonts-takao-mincho fonts-takao-gothic fonts-takao-pgothic -y""", True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Wrote 89 bytes.
# Out[2]: True</div>

# %%
display(dbutils.fs.ls("dbfs:/databricks/scripts/japanese-font-install.sh"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/databricks/scripts/japanese-font-install.sh</td><td>japanese-font-install.sh</td><td>89</td></tr></tbody></table></div>
